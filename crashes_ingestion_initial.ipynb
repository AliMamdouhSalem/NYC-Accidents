# %%
import pandas as pd
import requests
from datetime import date

# %%
columns=['collision_id',
 'crash_date',
 'crash_time',
 'borough',
 'latitude',
 'longitude',
 'on_street_name',
 'cross_street_name',
 'off_street_name',
 'number_of_persons_injured',
 'number_of_persons_killed',
 'number_of_pedestrians_injured',
 'number_of_pedestrians_killed',
 'number_of_cyclist_injured',
 'number_of_cyclist_killed',
 'number_of_motorist_injured',
 'number_of_motorist_killed',
 'contributing_factor_vehicle_1',
 'contributing_factor_vehicle_2',
 'contributing_factor_vehicle_3',
 'contributing_factor_vehicle_4',
 'contributing_factor_vehicle_5',
 'vehicle_type_code1',
 'vehicle_type_code2',
 'vehicle_type_code3',
 'vehicle_type_code4',
 'vehicle_type_code5']

# %%
today='\''
today= today + (date.today().strftime('%Y-%m-%d' )) + '\''
print(isinstance(today,str))
# Out:
# True

# %%
link=f'https://data.cityofnewyork.us/resource/h9gi-nx95.json?$where=crash_date between \'2024-05-22\' and \'2024-05-26\' '
response = requests.get(link).json()
print(len(response))
# Out:
# 0

# %%
offset=0 
sesh=requests.session()
data=[]
s=0
link=f'https://data.cityofnewyork.us/resource/h9gi-nx95.json?$offset={offset}'
response = requests.get(link).json()
while len(response)>0:
    link=f'https://data.cityofnewyork.us/resource/h9gi-nx95.json?$offset={offset}'
    response = requests.get(link).json()
    if isinstance(response,str):
        print('Error retrieving data, retrying')
    else:
        for i in response:
            record=[]
            for j in columns:
                if j in list(i.keys()):
                    record.append(i[j])
                else:
                    record.append(None)
            data.append(record)
            s=s+1
        offset=offset+1000
        print(f'{offset} records were loaded to the dataframe successfully')
# Out:
# 1000 records were loaded to the dataframe successfully
# 2000 records were loaded to the dataframe successfully
# 3000 records were loaded to the dataframe successfully
# 4000 records were loaded to the dataframe successfully
# 5000 records were loaded to the dataframe successfully
# 6000 records were loaded to the dataframe successfully
# 7000 records were loaded to the dataframe successfully
# 8000 records were loaded to the dataframe successfully
# 9000 records were loaded to the dataframe successfully
# 10000 records were loaded to the dataframe successfully
# 11000 records were loaded to the dataframe successfully
# 12000 records were loaded to the dataframe successfully
# 13000 records were loaded to the dataframe successfully
# 14000 records were loaded to the dataframe successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
# ...

# %%
crashes= pd.DataFrame(data=data,columns=columns)

# %%
crashes.astype({'number_of_persons_injured':'int64','number_of_persons_killed':'int64',
                'number_of_pedestrians_injured':'int64','number_of_pedestrians_killed':'int64'
               ,'number_of_cyclist_injured':'int64','number_of_cyclist_killed':'int64'
               ,'number_of_motorist_injured':'int64','number_of_motorist_killed':'int64'}).dtypes
# Out:
# collision_id                     object
# crash_date                       object
# crash_time                       object
# borough                          object
# latitude                         object
# longitude                        object
# on_street_name                   object
# cross_street_name                object
# off_street_name                  object
# number_of_persons_injured         int64
# number_of_persons_killed          int64
# number_of_pedestrians_injured     int64
# number_of_pedestrians_killed      int64
# number_of_cyclist_injured         int64
# number_of_cyclist_killed          int64
# number_of_motorist_injured        int64
# number_of_motorist_killed         int64
# contributing_factor_vehicle_1    object
# contributing_factor_vehicle_2    object
# contributing_factor_vehicle_3    object
# contributing_factor_vehicle_4    object
# contributing_factor_vehicle_5    object
# vehicle_type_code1               object
# ...

# %%
crashes= crashes.astype({'number_of_persons_injured':'int64','number_of_persons_killed':'int64',
                'number_of_pedestrians_injured':'int64','number_of_pedestrians_killed':'int64'
               ,'number_of_cyclist_injured':'int64','number_of_cyclist_killed':'int64'
               ,'number_of_motorist_injured':'int64','number_of_motorist_killed':'int64'})

# %%
crashes.dtypes
# Out:
# collision_id                     object
# crash_date                       object
# crash_time                       object
# borough                          object
# latitude                         object
# longitude                        object
# on_street_name                   object
# cross_street_name                object
# off_street_name                  object
# number_of_persons_injured         int64
# number_of_persons_killed          int64
# number_of_pedestrians_injured     int64
# number_of_pedestrians_killed      int64
# number_of_cyclist_injured         int64
# number_of_cyclist_killed          int64
# number_of_motorist_injured        int64
# number_of_motorist_killed         int64
# contributing_factor_vehicle_1    object
# contributing_factor_vehicle_2    object
# contributing_factor_vehicle_3    object
# contributing_factor_vehicle_4    object
# contributing_factor_vehicle_5    object
# vehicle_type_code1               object
# ...

# %%
crashes['crash_date'] = pd.to_datetime(crashes['crash_date'])

# %%
crashes
# Out:
#       collision_id crash_date crash_time   borough   latitude   longitude  \
# 0          4455765 2021-09-11       2:39      None       None        None
# 1          4513547 2022-03-26      11:45      None       None        None
# 2          4541903 2022-06-29       6:55      None       None        None
# 3          4456314 2021-09-11       9:35  BROOKLYN  40.667202    -73.8665
# 4          4486609 2021-12-14       8:13  BROOKLYN  40.683304  -73.917274
# ...            ...        ...        ...       ...        ...         ...
# 13995      4415088 2021-05-04      10:45    QUEENS   40.71491   -73.83194
# 13996      4414406 2021-05-08       6:00  BROOKLYN  40.603344   -73.93684
# 13997      4415132 2021-05-01      18:30    QUEENS   40.71871  -73.763176
# 13998      4414555 2021-05-08      10:30     BRONX    40.8566   -73.82646
# 13999      4414811 2021-05-08      18:20      None   40.59113   -74.16521
#
#                 on_street_name           cross_street_name off_street_name  \
# ...

# %%
import pandas as pd
import requests

# %%
link=f'https://data.cityofnewyork.us/resource/f55k-p6yu.json?$offset=0'
response = requests.get(link).json()
print(list(response[600].keys()))
# Out:
# ['unique_id', 'collision_id', 'crash_date', 'crash_time', 'person_id', 'person_type', 'person_injury', 'vehicle_id', 'ped_role', 'person_sex']

# %%
columns=['unique_id', 'collision_id', 'crash_date', 'crash_time', 'person_id', 'person_type', 'person_injury',
 'vehicle_id', 'person_age', 'ejection', 'emotional_status', 
 'bodily_injury', 'position_in_vehicle', 'safety_equipment', 'ped_location','ped_action','complaint', 
 'ped_role','contributing_factor_1','contributing_factor_1', 'person_sex']

# %%
offset=0 
data=[]
s=0
link=f'https://data.cityofnewyork.us/resource/f55k-p6yu.json?$offset={offset}'
response = requests.get(link).json()
while len(response)>0:
    link=f'https://data.cityofnewyork.us/resource/f55k-p6yu.json?$offset={offset}'
    response = requests.get(link).json()
    for i in response:
        record=[]
        for j in columns:
            if j in list(i.keys()):
                record.append(i[j])
            else:
                record.append(None)
        data.append(record)
        s=s+1
    offset=offset+1000
    print(f'{offset} records were loaded to the dataframe successfully')
# Out:
# 1000 records were loaded to the dataframe successfully
# 2000 records were loaded to the dataframe successfully
# 3000 records were loaded to the dataframe successfully
# 4000 records were loaded to the dataframe successfully
# 5000 records were loaded to the dataframe successfully
# 6000 records were loaded to the dataframe successfully
# 7000 records were loaded to the dataframe successfully
# 8000 records were loaded to the dataframe successfully
# 9000 records were loaded to the dataframe successfully
# 10000 records were loaded to the dataframe successfully
# 11000 records were loaded to the dataframe successfully
# 12000 records were loaded to the dataframe successfully
# 13000 records were loaded to the dataframe successfully
# 14000 records were loaded to the dataframe successfully
# 15000 records were loaded to the dataframe successfully
# 16000 records were loaded to the dataframe successfully
# 17000 records were loaded to the dataframe successfully
# ...

# %%
people= pd.DataFrame(data=data,columns=columns)

# %%
people
# Out:
#        unique_id collision_id               crash_date crash_time  \
# 0       10249006      4229554  2019-10-26T00:00:00.000       9:43
# 1       10255054      4230587  2019-10-25T00:00:00.000      15:15
# 2       10253177      4230550  2019-10-26T00:00:00.000      17:55
# 3        6650180      3565527  2016-11-21T00:00:00.000      13:05
# 4       10255516      4231168  2019-10-25T00:00:00.000      11:16
# ...          ...          ...                      ...        ...
# 103995   8985621      4068506  2019-01-24T00:00:00.000      21:45
# 103996   6217046      3459258  2016-06-08T00:00:00.000      15:55
# 103997  10002088      4172062  2019-07-17T00:00:00.000       1:00
# 103998   5774009      3408615  2016-03-25T00:00:00.000      18:50
# 103999   9129857      3915734  2018-06-06T00:00:00.000       7:46
#
#                                    person_id person_type person_injury  \
# 0       31aa2bc0-f545-444f-8cdb-f1cb5cf00b89    Occupant   Unspecified
# ...
